# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/mericyasar/ligo-microseism
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ligo-microseism (pyproject.toml) ... done
#   Created wheel for ligo-microseism: filename=ligo_microseism-0.1.0-0.editable-py3-none-any.whl size=1772 sha256=51cebff8b12a74cc8231b3947bf9bdcbe848a15fc9d0ecb43e13c8da8cadb70e
#   Stored in directory: /private/var/folders/x7/8bm7lncd6l72hddvqjf4pb2c0000gn/T/pip-ephem-wheel-cache-05e4v06p/wheels/34/9b/0e/69265e36a50e62e21076b9ff0c6b80b4769af61a167ea4734c
# Successfully built ligo-microseism
# ...
#   Attempting uninstall: ligo-microseism
#     Found existing installation: ligo-microseism 0.1.0
#     Uninstalling ligo-microseism-0.1.0:
#       Successfully uninstalled ligo-microseism-0.1.0
# ...

# %%
# %matplotlib inline
# %run scripts/run_fir.py
# Out:
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# LIGO Microseism Pipeline
# Cavity: DARM | Run Type: Sweep | Training: Noisy
# Frequency: 4.0 Hz | Frequency Band: (0.03, 0.25)
# Taps: 265 | Causality Gap: 4 | Bandpass Training: True
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Loaded 1424916018
# Loaded 1420675218
# Loaded 1422266402
# Loaded 1417615060
# Loaded 1417838418
# Loaded 1422316818
# Loaded 1424689218
# Loaded 1420416018
# Loaded 1418934929
# Loaded 1420851618
# Loaded 1424736018
# Loaded 1417846196
# Loaded 1420344018
# Loaded 1423267218
# Loaded 1423274418
# Loaded 15 Noisy folders for fitting
#
# Loaded total of 15 folders into library
#
# --- Starting Sweep Evaluation ---
#  Alpha 1e-05 -> Avg LOFO CRMS: 0.1414
#  Alpha 1e-07 -> Avg LOFO CRMS: 0.1264
# Winning Alpha: 1e-07 | Avg LOFO CRMS: 0.1264
# Evaluating LOFO Training splits
# Fitting is complete.
# ...
# DARM SWEEP SUPPRESSION STATISTICS
# ...
