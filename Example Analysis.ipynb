# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/mericyasar/ligo-microseism
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.24 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from ligo-microseism==0.1.0) (2.4.1)
# Requirement already satisfied: scipy>=1.11 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from ligo-microseism==0.1.0) (1.16.3)
# Requirement already satisfied: pandas>=2.0 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from ligo-microseism==0.1.0) (2.3.3)
# Requirement already satisfied: matplotlib>=3.7 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from ligo-microseism==0.1.0) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from matplotlib>=3.7->ligo-microseism==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from matplotlib>=3.7->ligo-microseism==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from matplotlib>=3.7->ligo-microseism==0.1.0) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from matplotlib>=3.7->ligo-microseism==0.1.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from matplotlib>=3.7->ligo-microseism==0.1.0) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from matplotlib>=3.7->ligo-microseism==0.1.0) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from matplotlib>=3.7->ligo-microseism==0.1.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from matplotlib>=3.7->ligo-microseism==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from pandas>=2.0->ligo-microseism==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from pandas>=2.0->ligo-microseism==0.1.0) (2026.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->ligo-microseism==0.1.0) (1.17.0)
# Building wheels for collected packages: ligo-microseism
#   Building editable for ligo-microseism (pyproject.toml) ... done
#   Created wheel for ligo-microseism: filename=ligo_microseism-0.1.0-0.editable-py3-none-any.whl size=2620 sha256=78dd18f06b01b7904a455acbd4c30c4c0f5eb4d8281a68ccc8d088f1c42d7d2e
#   Stored in directory: /private/var/folders/x7/8bm7lncd6l72hddvqjf4pb2c0000gn/T/pip-ephem-wheel-cache-qdorb6qq/wheels/34/9b/0e/69265e36a50e62e21076b9ff0c6b80b4769af61a167ea4734c
# Successfully built ligo-microseism
# Installing collected packages: ligo-microseism
#   Attempting uninstall: ligo-microseism
#     Found existing installation: ligo-microseism 0.1.0
#     Uninstalling ligo-microseism-0.1.0:
#       Successfully uninstalled ligo-microseism-0.1.0
# Successfully installed ligo-microseism-0.1.0

# %%
# %matplotlib inline
import subprocess
for c in ("SRCL", "MICH", "FC", "IMC"):
    print(f"\n{'='*60}\n{c}\n{'='*60}")
    subprocess.run(["python", "scripts/run_fir.py", "--cavity", c, "--eval-other"])
# Out:
# ============================================================
# SRCL
# ============================================================
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# LIGO Microseism Pipeline
# Cavity: SRCL | Run Type: Sweep | Training: Noisy
# Frequency: 4.0 Hz | Frequency Band: (0.03, 0.25)
# Taps: 265 | Causality Gap: 1 | Bandpass Training: True
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Loaded 1424916018
# Loaded 1420675218
# Loaded 1422266402
# Loaded 1417615060
# Loaded 1417838418
# Loaded 1422316818
# Loaded 1424689218
# Loaded 1420416018
# Loaded 1418934929
# Loaded 1420851618
# Loaded 1424736018
# Loaded 1417846196
# Loaded 1420344018
# Loaded 1423267218
# Loaded 1423274418
# Loaded 15 Noisy folders for fitting
# Loaded 1435708818
# Loaded 1435795218
# Loaded 1436227218
# Loaded 1440460818
# Loaded 1433462418
# Loaded 1434067218
# Loaded 1435276818
# Loaded 1435903098
# Loaded 1435968018
# Loaded 1436400018
# Loaded 1437652918
# Loaded 1434426707
# Loaded 1434512334
# Loaded 1434679218
# Loaded 1434844818
#
# Loaded total of 30 folders into library
#
# --- Starting Sweep Evaluation ---
# Folder evaluation is in progress...
#  Alpha 1e-05 -> Avg LOFO CRMS: 0.0399
#  Alpha 1e-07 -> Avg LOFO CRMS: 0.0398
#
# Winning Alpha: 1e-07 | Avg LOFO CRMS: 0.0398
# Evaluating LOFO Training splits
# Evaluating Master Filter on Other sets
# Fitting is complete.
#   wrote results/SRCL_Sweep_Noisy.json  (15 folders)
#   wrote results/SRCL_Sweep_Noisy.npz   (150 arrays)
#
# ============================================================
# MICH
# ============================================================
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# LIGO Microseism Pipeline
# Cavity: MICH | Run Type: Sweep | Training: Noisy
# Frequency: 4.0 Hz | Frequency Band: (0.03, 0.25)
# Taps: 265 | Causality Gap: 1 | Bandpass Training: True
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Loaded 1424916018
# Loaded 1420675218
# Loaded 1422266402
# Loaded 1417615060
# Loaded 1417838418
# Loaded 1422316818
# Loaded 1424689218
# Loaded 1420416018
# Loaded 1418934929
# Loaded 1420851618
# Loaded 1424736018
# Loaded 1417846196
# Loaded 1420344018
# Loaded 1423267218
# Loaded 1423274418
# Loaded 15 Noisy folders for fitting
# Loaded 1435708818
# Loaded 1435795218
# Loaded 1436227218
# Loaded 1440460818
# Loaded 1433462418
# Loaded 1434067218
# Loaded 1435276818
# Loaded 1435903098
# Loaded 1435968018
# Loaded 1436400018
# Loaded 1437652918
# Loaded 1434426707
# Loaded 1434512334
# Loaded 1434679218
# Loaded 1434844818
#
# Loaded total of 30 folders into library
#
# --- Starting Sweep Evaluation ---
# Folder evaluation is in progress...
#  Alpha 1e-05 -> Avg LOFO CRMS: 0.0387
#  Alpha 1e-07 -> Avg LOFO CRMS: 0.0386
#
# Winning Alpha: 1e-07 | Avg LOFO CRMS: 0.0386
# Evaluating LOFO Training splits
# Evaluating Master Filter on Other sets
# Fitting is complete.
#   wrote results/MICH_Sweep_Noisy.json  (15 folders)
#   wrote results/MICH_Sweep_Noisy.npz   (150 arrays)
#
# ============================================================
# FC
# ============================================================
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# LIGO Microseism Pipeline
# Cavity: FC | Run Type: Sweep | Training: Noisy
# Frequency: 4.0 Hz | Frequency Band: (0.03, 0.25)
# Taps: 265 | Causality Gap: 1 | Bandpass Training: True
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Loaded 1424916018
# Loaded 1420675218
# Loaded 1422266402
# Loaded 1417615060
# Loaded 1417838418
# Loaded 1422316818
# Loaded 1424689218
# Loaded 1420416018
# Loaded 1418934929
# Loaded 1420851618
# Loaded 1424736018
# Loaded 1417846196
# Loaded 1420344018
# Loaded 1423267218
# Loaded 1423274418
# Loaded 15 Noisy folders for fitting
# Loaded 1435708818
# Loaded 1435795218
# Loaded 1436227218
# Loaded 1440460818
# Loaded 1433462418
# Loaded 1434067218
# Loaded 1435276818
# Loaded 1435903098
# Loaded 1435968018
# Loaded 1436400018
# Loaded 1437652918
# Loaded 1434426707
# Loaded 1434512334
# Loaded 1434679218
# Loaded 1434844818
#
# Loaded total of 30 folders into library
#
# --- Starting Sweep Evaluation ---
# Folder evaluation is in progress...
#  Alpha 1e-05 -> Avg LOFO CRMS: 0.1776
#  Alpha 1e-07 -> Avg LOFO CRMS: 0.1761
#
# Winning Alpha: 1e-07 | Avg LOFO CRMS: 0.1761
# Evaluating LOFO Training splits
# Evaluating Master Filter on Other sets
# Fitting is complete.
#   wrote results/FC_Sweep_Noisy.json  (15 folders)
#   wrote results/FC_Sweep_Noisy.npz   (150 arrays)
#
# ============================================================
# IMC
# ============================================================
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# LIGO Microseism Pipeline
# Cavity: IMC | Run Type: Sweep | Training: Noisy
# Frequency: 4.0 Hz | Frequency Band: (0.03, 0.25)
# Taps: 265 | Causality Gap: 1 | Bandpass Training: True
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Loaded 1424916018
# Loaded 1420675218
# Loaded 1422266402
# Loaded 1417615060
# Loaded 1417838418
# Loaded 1422316818
# Loaded 1424689218
# Loaded 1420416018
# Loaded 1418934929
# Loaded 1420851618
# Loaded 1424736018
# Loaded 1417846196
# Loaded 1420344018
# Loaded 1423267218
# Loaded 1423274418
# Loaded 15 Noisy folders for fitting
# Loaded 1435708818
# Loaded 1435795218
# Loaded 1436227218
# Loaded 1440460818
# Loaded 1433462418
# Loaded 1434067218
# Loaded 1435276818
# Loaded 1435903098
# Loaded 1435968018
# Loaded 1436400018
# Loaded 1437652918
# Loaded 1434426707
# Loaded 1434512334
# Loaded 1434679218
# Loaded 1434844818
#
# Loaded total of 30 folders into library
#
# --- Starting Sweep Evaluation ---
# Folder evaluation is in progress...
#  Alpha 1e-05 -> Avg LOFO CRMS: 0.0311
#  Alpha 1e-07 -> Avg LOFO CRMS: 0.0309
#
# Winning Alpha: 1e-07 | Avg LOFO CRMS: 0.0309
# Evaluating LOFO Training splits
# Evaluating Master Filter on Other sets
# Fitting is complete.
#   wrote results/IMC_Sweep_Noisy.json  (15 folders)
#   wrote results/IMC_Sweep_Noisy.npz   (150 arrays)

# %%
# %run scripts/make_figures.py --cavity ALL --run-type Sweep
# Out:
# Summary table:
#   wrote results/summary_Sweep_Noisy.csv  (90 rows)
#
# DARM  (run 2026-08-06T17:21:27+00:00)
#   figure -> figures/DARM_bode.pdf
#
# ================================================================
# DARM SWEEP SUPPRESSION STATISTICS
# ================================================================
# Number of plotted blind realizations : 15
# Mean suppression                    : 8.18 ± 0.40
# ================================================================
#   figure -> figures/DARM_suppression.pdf
#   figure -> figures/DARM_suppression_vs_blrms.pdf
#
# PRCL  (run 2026-08-06T17:22:56+00:00)
#   figure -> figures/PRCL_bode.pdf
#
# ================================================================
# PRCL SWEEP SUPPRESSION STATISTICS
# ================================================================
# Number of plotted blind realizations : 15
# Mean suppression                    : 25.26 ± 0.97
# ================================================================
#   figure -> figures/PRCL_suppression.pdf
#   figure -> figures/PRCL_suppression_vs_blrms.pdf
#
# SRCL  (run 2026-08-06T18:15:41+00:00)
#   figure -> figures/SRCL_bode.pdf
#
# ================================================================
# SRCL SWEEP SUPPRESSION STATISTICS
# ================================================================
# Number of plotted blind realizations : 15
# Mean suppression                    : 24.58 ± 0.77
# ================================================================
#   figure -> figures/SRCL_suppression.pdf
#   figure -> figures/SRCL_suppression_vs_blrms.pdf
#
# MICH  (run 2026-08-06T18:16:33+00:00)
#   figure -> figures/MICH_bode.pdf
#
# ================================================================
# MICH SWEEP SUPPRESSION STATISTICS
# ================================================================
# Number of plotted blind realizations : 15
# Mean suppression                    : 25.04 ± 1.58
# ================================================================
#   figure -> figures/MICH_suppression.pdf
#   figure -> figures/MICH_suppression_vs_blrms.pdf
#
# IMC  (run 2026-08-06T18:19:25+00:00)
#   figure -> figures/IMC_bode.pdf
#
# ================================================================
# IMC SWEEP SUPPRESSION STATISTICS
# ================================================================
# Number of plotted blind realizations : 15
# Mean suppression                    : 31.04 ± 0.68
# ================================================================
#   figure -> figures/IMC_suppression.pdf
#   figure -> figures/IMC_suppression_vs_blrms.pdf
#
# FC  (run 2026-08-06T18:18:02+00:00)
#   figure -> figures/FC_bode.pdf
#
# ================================================================
# FC SWEEP SUPPRESSION STATISTICS
# ================================================================
# Number of plotted blind realizations : 15
# Mean suppression                    : 5.38 ± 0.22
# ================================================================
#   figure -> figures/FC_suppression.pdf
#   figure -> figures/FC_suppression_vs_blrms.pdf
# /opt/anaconda3/envs/NeuralN/lib/python3.11/site-packages/IPython/core/pylabtools.py:233: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
