# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/mericyasar/ligo-microseism
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for ligo-microseism (pyproject.toml) ... done
#   Created wheel for ligo-microseism: filename=ligo_microseism-0.1.0-0.editable-py3-none-any.whl size=2673 sha256=057630443b1132e56866faa09ff7dfd41aaa7156f0d9b3c654c9e9af1a15d666
#   Stored in directory: /private/var/folders/x7/8bm7lncd6l72hddvqjf4pb2c0000gn/T/pip-ephem-wheel-cache-mm9afhqk/wheels/34/9b/0e/69265e36a50e62e21076b9ff0c6b80b4769af61a167ea4734c
# Successfully built ligo-microseism
# ...
#   Attempting uninstall: ligo-microseism
#     Found existing installation: ligo-microseism 0.1.0
#     Uninstalling ligo-microseism-0.1.0:
#       Successfully uninstalled ligo-microseism-0.1.0
# ...

# %%
# %matplotlib inline
# %run scripts/run_fir.py 
# %run scripts/make_figures.py
# Out:
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# LIGO Microseism Pipeline
# Cavity: DARM | Run Type: Blind | Training: Noisy
# Frequency: 4.0 Hz | Frequency Band: (0.03, 0.25)
# Taps: 265 | Causality Gap: 0 | Bandpass Training: True
# :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
# Loaded 1424916018
# Loaded 1420675218
# Loaded 1422266402
# Loaded 1417615060
# Loaded 1422316818
# Loaded 1424689218
# Loaded 1420416018
# Loaded 1418934929
# Loaded 1420851618
# Loaded 1424736018
# Loaded 1417846196
# Loaded 1420344018
# Loaded 1423267218
# Loaded 1423274418
# Loaded 14 Noisy folders for fitting
# Loaded 1417838418
#
# Loaded total of 15 folders into library
#
# --- Starting LOFO Training ---
#  Alpha 1e-05 -> Avg LOFO CRMS: 0.1215
#  Alpha 1e-07 -> Avg LOFO CRMS: 0.1196
#
# Winning Alpha: 1e-07 | Avg LOFO CRMS: 0.1196
#
# --- Starting Blind Evaluation ---
# Evaluating 1417838418...
# ...
